# %%
from all_dataframes import (
    load_base_df,
    create_weather_df,
    create_environment_df,
    create_time_df,
    create_geo_df,
    create_light_df
)

df = load_base_df("C:/Users/serko/US_ACCIDENTS/US_Accidents_March23.csv")

weather_df = create_weather_df(df)
environment_df = create_environment_df(df)
time_df = create_time_df(df)
geo_df = create_geo_df(df)
light_df = create_light_df(df)
# Out:
# all_dataframes.py loaded successfully
# Base DataFrame loaded.
# Rows: 7728394
# Columns: 46
#
# weather_df created.
# Rows: 7728394
# Columns: 12
# root
#  |-- ID: string (nullable = true)
#  |-- Weather_Timestamp: timestamp (nullable = true)
#  |-- Temperature(F): double (nullable = true)
#  |-- Wind_Chill(F): double (nullable = true)
#  |-- Humidity(%): double (nullable = true)
#  |-- Pressure(in): double (nullable = true)
#  |-- Visibility(mi): double (nullable = true)
#  |-- Wind_Direction: string (nullable = true)
#  |-- Wind_Speed(mph): double (nullable = true)
#  |-- Precipitation(in): double (nullable = true)
#  |-- Weather_Condition: string (nullable = true)
#  |-- Airport_Code: string (nullable = true)
#
#
# environment_df created.
# Rows: 7728394
# Columns: 14
# root
#  |-- ID: string (nullable = true)
#  |-- Amenity: boolean (nullable = true)
#  |-- Give_Way: boolean (nullable = true)
#  |-- Bump: boolean (nullable = true)
#  |-- Crossing: boolean (nullable = true)
# ...
